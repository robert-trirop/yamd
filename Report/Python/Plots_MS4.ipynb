# %%
from matplotlib import pyplot as plt
lines = [float(line.rstrip()) for line in open(r'/home/trirop/yamd/Data/Out_MS4/energies.txt','r')]
plt.plot(lines, linewidth=0.2);
plt.savefig("file.jpeg", dpi=2000)
